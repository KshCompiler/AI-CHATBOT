# %%
import os
from dotenv import load_dotenv
load_dotenv()
from langchain.chat_models import init_chat_model
from langgraph.graph import StateGraph,START,END
from langgraph.graph.message import add_messages
from typing import Annotated, List
from pydantic import BaseModel

#model
llm = init_chat_model(
    model="llama-3.3-70b-versatile",
    model_provider="groq",
)
#state
class state(BaseModel):
    messages:Annotated[List,add_messages]
     
graph_builder = StateGraph(state)

#node
def chatbot(State:state):
    return {"messages": [llm.invoke(State.messages)]}

graph_builder.add_node("chatbot", chatbot)  
graph_builder.add_edge(START, "chatbot")
graph_builder.add_edge("chatbot", END)

graph = graph_builder.compile()

# %%
import os
from dotenv import load_dotenv
load_dotenv()
from langchain.chat_models import init_chat_model
from langgraph.graph import StateGraph,START,END
from langgraph.graph.message import add_messages
from typing import Annotated, List
from pydantic import BaseModel

#model
llm = init_chat_model(
    model="llama-3.3-70b-versatile",
    model_provider="groq",
)
#state
class state(BaseModel):
    messages:Annotated[List,add_messages]
     
graph_builder = StateGraph(state)

#node
def chatbot(State:state):
    return {"messages": [llm.invoke(State.messages)]}

graph_builder.add_node("chatbot", chatbot)
graph_builder.add_edge(START, "chatbot")
graph_builder.add_edge("chatbot", END)

graph = graph_builder.compile()

response = graph.invoke({"messages": [{"role": "user", "content": "write hundred lines of something"}]})
print(response["messages"][-1].content, end = "")
# Out:
# Here are 100 lines of text:
#
# 1. The sun rises over the horizon, a new day begins.
# 2. The birds sing their sweet melodies, a symphony of sound.
# 3. The world awakens from its slumber, a fresh start unfolds.
# 4. The morning light creeps over the landscape, a warm glow.
# 5. The stars fade away, their twinkling lights extinguished.
# 6. The moon hides its face, a silver crescent disappears.
# 7. The clouds drift lazily by, a gentle breeze stirs.
# 8. The trees sway softly, their leaves rustling free.
# 9. The flowers bloom, a colorful display of beauty.
# 10. The bees buzz, collecting nectar with busy glee.
# 11. The butterflies dance, their wings a blur of color.
# 12. The world is full of wonder, a magical place to be.
# 13. The sun shines bright, a warm and comforting light.
# 14. The air is filled with the sweet scent of blooming flowers.
# 15. The sound of laughter echoes, a joyful noise.
# 16. The smell of freshly cut grass wafts, a nostalgic aroma.
# 17. The feeling of freedom is exhilarating, a sense of release.
# 18. The world is a beautiful place, full of surprises.
# 19. The sun sets slowly, a fiery ball of orange and red.
# 20. The stars twinkle like diamonds, a night sky filled with wonder.
# 21. The moon glows with a soft light, a gentle beacon.
# 22. The world is full of mystery, a place of enchantment.
# 23. The darkness falls, a time for rest and sleep.
# 24. The dreams begin, a journey of the imagination.
# 25. The subconscious mind takes over, a world of fantasy.
# 26. The boundaries of reality are pushed, a realm of possibility.
# 27. The mind is a powerful tool, a source of creativity.
# 28. The thoughts and ideas flow, a never-ending stream.
# 29. The imagination knows no bounds, a limitless expanse.
# 30. The world of dreams is a place of wonder, a realm of magic.
# 31. The sun rises again, a new day dawns.
# 32. The cycle begins anew, a fresh start unfolds.
# 33. The world is full of hope, a sense of promise.
# 34. The future is uncertain, a path yet to be taken.
# 35. The choices we make, shape the course of our lives.
# 36. The decisions we take, determine our destiny.
# 37. The journey of life is a long and winding road.
# 38. The twists and turns, lead us to unexpected places.
# 39. The surprises we encounter, shape our character.
# 40. The challenges we face, test our resolve and strength.
# 41. The obstacles we overcome, make us stronger and wiser.
# 42. The lessons we learn, guide us on our way.
# 43. The experiences we have, shape our perspective.
# 44. The people we meet, influence our lives.
# 45. The relationships we form, bring joy and love.
# 46. The memories we create, last a lifetime.
# 47. The moments we share, are precious and fleeting.
# 48. The love we give, is a gift from the heart.
# 49. The kindness we show, is a reflection of our soul.
# 50. The compassion we feel, is a fundamental part of our humanity.
# 51. The world is a complex and multifaceted place.
# 52. The issues we face, are numerous and challenging.
# 53. The problems we encounter, require creative solutions.
# 54. The answers we seek, are often hidden in plain sight.
# 55. The truth we search for, is a elusive and mysterious thing.
# 56. The questions we ask, lead us to new discoveries.
# 57. The pursuit of knowledge, is a lifelong journey.
# 58. The quest for understanding, is a fundamental human drive.
# 59. The desire to learn, is a powerful force.
# 60. The love of wisdom, is a guiding principle.
# 61. The world is full of beauty, a treasure trove of wonder.
# 62. The natural world, is a source of inspiration.
# 63. The beauty of nature, is a gift to behold.
# 64. The complexity of the universe, is a mystery to unravel.
# 65. The secrets of the cosmos, are waiting to be discovered.
# 66. The wonders of the world, are a source of awe and wonder.
# 67. The magic of life, is a precious and fragile thing.
# 68. The importance of living, is a fundamental truth.
# 69. The value of experience, is a lesson learned.
# 70. The power of love, is a transformative force.
# 71. The impact of kindness, is a ripple effect.
# 72. The influence of compassion, is a profound and lasting thing.
# 73. The world is a better place, when we show empathy and care.
# 74. The connections we make, are a source of strength.
# 75. The bonds we form, are a foundation for growth.
# 76. The relationships we nurture, are a source of joy and love.
# 77. The memories we create, are a treasure to behold.
# 78. The moments we share, are precious and fleeting.
# 79. The love we give, is a gift from the heart.
# 80. The kindness we show, is a reflection of our soul.
# 81. The world is a complex and multifaceted place.
# 82. The issues we face, are numerous and challenging.
# 83. The problems we encounter, require creative solutions.
# 84. The answers we seek, are often hidden in plain sight.
# 85. The truth we search for, is a elusive and mysterious thing.
# 86. The questions we ask, lead us to new discoveries.
# 87. The pursuit of knowledge, is a lifelong journey.
# 88. The quest for understanding, is a fundamental human drive.
# 89. The desire to learn, is a powerful force.
# 90. The love of wisdom, is a guiding principle.
# 91. The world is full of wonder, a magical place to be.
# 92. The beauty of life, is a precious and fragile thing.
# 93. The importance of living, is a fundamental truth.
# 94. The value of experience, is a lesson learned.
# 95. The power of love, is a transformative force.
# 96. The impact of kindness, is a ripple effect.
# 97. The influence of compassion, is a profound and lasting thing.
# 98. The world is a better place, when we show empathy and care.
# 99. The connections we make, are a source of strength.
# 100. The love we share, is a gift that will forever last.
